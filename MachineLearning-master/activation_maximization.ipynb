# %% [markdown]
# # Activation Maximization on MNIST

# %% [markdown]
# Lets build the mnist model and train it for 5 epochs. It should get to about ~99% test accuracy.

# %%
from __future__ import print_function

import numpy as np
import keras

from keras.datasets import mnist
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Flatten, Activation, Input
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K

batch_size = 128
num_classes = 10
epochs = 5

# input image dimensions
img_rows, img_cols = 28, 28

# the data, shuffled and split between train and test sets
(x_train, y_train), (x_test, y_test) = mnist.load_data()

if K.image_data_format() == 'channels_first':
    x_train = x_train.reshape(x_train.shape[0], 1, img_rows, img_cols)
    x_test = x_test.reshape(x_test.shape[0], 1, img_rows, img_cols)
    input_shape = (1, img_rows, img_cols)
else:
    x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, 1)
    x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, 1)
    input_shape = (img_rows, img_cols, 1)

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3),
                 activation='relu',
                 input_shape=input_shape))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax', name='preds'))

model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.Adam(),
              metrics=['accuracy'])

model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(x_test, y_test))

score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Using TensorFlow backend.
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 5s 91us/step - loss: 0.2336 - acc: 0.9301 - val_loss: 0.0519 - val_acc: 0.9817
# Epoch 2/5
# 60000/60000 [==============================] - 4s 70us/step - loss: 0.0800 - acc: 0.9759 - val_loss: 0.0354 - val_acc: 0.9878
# Epoch 3/5
# 60000/60000 [==============================] - 4s 72us/step - loss: 0.0585 - acc: 0.9824 - val_loss: 0.0339 - val_acc: 0.9887
# Epoch 4/5
# 60000/60000 [==============================] - 4s 70us/step - loss: 0.0481 - acc: 0.9850 - val_loss: 0.0298 - val_acc: 0.9892
# Epoch 5/5
# 60000/60000 [==============================] - 5s 75us/step - loss: 0.0432 - acc: 0.9865 - val_loss: 0.0257 - val_acc: 0.9916
# Test loss: 0.025691429764159692
# Test accuracy: 0.9916

# %% [markdown]
# ## Dense Layer Visualizations

# %% [markdown]
# To visualize activation over final dense layer outputs, we need to switch the `softmax` activation out for `linear` since gradient of output node will depend on all the other node activations. Doing this in keras is tricky, so we provide `utils.apply_modifications` to modify network parameters and rebuild the graph.
#
# If this swapping is not done, the results might be suboptimal. We will start by swapping out 'softmax' for 'linear' and compare what happens if we dont do this at the end.

# %% [markdown]
# Lets start by visualizing input that maximizes the output of node 0. Hopefully this looks like a 0.

# %%
from vis.visualization import visualize_activation
from vis.utils import utils
from keras import activations

from matplotlib import pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (18, 6)

# Utility to search for layer index by name. 
# Alternatively we can specify this as -1 since it corresponds to the last layer.
layer_idx = utils.find_layer_idx(model, 'preds')

# Swap softmax with linear
model.layers[layer_idx].activation = activations.linear
model = utils.apply_modifications(model)

# This is the output node we want to maximize.
filter_idx = 0
img = visualize_activation(model, layer_idx, filter_indices=filter_idx)
plt.imshow(img[..., 0])

# %% [markdown]
# Hmm, it sort of looks like a 0, but not as clear as we hoped for. Activation maximization is notorious because regularization parameters needs to be tuned depending on the problem. Lets enumerate all the possible reasons why this didn't work very well.
#
# - The input to network is preprocessed to range (0, 1). We should specify `input_range = (0., 1.)` to constrain the input to this range.
# - The regularization parameter default weights might be dominating activation maximization loss weight. One way to debug this is to use `verbose=True` and examine individual loss values.
#
# Lets do these step by step and see if we can improve it.

# %% [markdown]
# ### Debugging step 1: Specifying input_range

# %%
img = visualize_activation(model, layer_idx, filter_indices=filter_idx, input_range=(0., 1.))
plt.imshow(img[..., 0])

# %% [markdown]
# Much better but still seems noisy. Lets examining the losses with `verbose=True` and tuning the weights.

# %% [markdown]
# ### Debugging step 2: Tuning regularization weights

# %% [markdown]
# One of the issues with activation maximization is that the input can go out of the training distribution space. Total variation and L-p norm are used to provide some hardcoded image priors for natural images. For example, Total variation ensures that images are blobber and not scattered. Unfotunately, sometimes these losses can dominate the main `ActivationMaximization` loss.
#
# Lets see what individual losses are, with `verbose=True`

# %%
img = visualize_activation(model, layer_idx, filter_indices=filter_idx, input_range=(0., 1.), verbose=True)
plt.imshow(img[..., 0])
# Out:
# Iteration: 1, named_losses: [('ActivationMax Loss', -0.02699059),
#  ('L-6.0 Norm Loss', 0.019829987),
#  ('TV(2.0) Loss', 0.094678916)], overall loss: 0.08751831203699112
# Iteration: 2, named_losses: [('ActivationMax Loss', 7.987387),
#  ('L-6.0 Norm Loss', 0.17138307),
#  ('TV(2.0) Loss', 516.50287)], overall loss: 524.66162109375
# Iteration: 3, named_losses: [('ActivationMax Loss', -105.02654),
#  ('L-6.0 Norm Loss', 0.17312692),
#  ('TV(2.0) Loss', 129.0684)], overall loss: 24.214988708496094
# Iteration: 4, named_losses: [('ActivationMax Loss', -215.75992),
#  ('L-6.0 Norm Loss', 0.20199749),
#  ('TV(2.0) Loss', 147.34914)], overall loss: -68.20878601074219
# Iteration: 5, named_losses: [('ActivationMax Loss', -337.05112),
#  ('L-6.0 Norm Loss', 0.24427196),
#  ('TV(2.0) Loss', 147.39551)], overall loss: -189.41134643554688
# Iteration: 6, named_losses: [('ActivationMax Loss', -438.41516),
#  ('L-6.0 Norm Loss', 0.2787507),
#  ('TV(2.0) Loss', 176.98161)], overall loss: -261.15478515625
# Iteration: 7, named_losses: [('ActivationMax Loss', -522.045),
#  ('L-6.0 Norm Loss', 0.31626782),
#  ('TV(2.0) Loss', 211.77011)], overall loss: -309.9585876464844
# Iteration: 8, named_losses: [('ActivationMax Loss', -593.8919),
#  ('L-6.0 Norm Loss', 0.3464589),
#  ('TV(2.0) Loss', 241.76585)], overall loss: -351.77960205078125
# Iteration: 9, named_losses: [('ActivationMax Loss', -654.2061),
#  ('L-6.0 Norm Loss', 0.38058373),
#  ('TV(2.0) Loss', 268.59256)], overall loss: -385.2330017089844
# Iteration: 10, named_losses: [('ActivationMax Loss', -706.9933),
#  ('L-6.0 Norm Loss', 0.4082707),
#  ('TV(2.0) Loss', 294.57056)], overall loss: -412.01446533203125
# Iteration: 11, named_losses: [('ActivationMax Loss', -752.97736),
#  ('L-6.0 Norm Loss', 0.4387512),
#  ('TV(2.0) Loss', 322.96576)], overall loss: -429.5728759765625
# Iteration: 12, named_losses: [('ActivationMax Loss', -792.34644),
#  ('L-6.0 Norm Loss', 0.4630493),
#  ('TV(2.0) Loss', 334.50748)], overall loss: -457.3758850097656
# Iteration: 13, named_losses: [('ActivationMax Loss', -823.09766),
#  ('L-6.0 Norm Loss', 0.48804834),
#  ('TV(2.0) Loss', 354.78488)], overall loss: -467.8247375488281
# Iteration: 14, named_losses: [('ActivationMax Loss', -853.5583),
#  ('L-6.0 Norm Loss', 0.51094764),
#  ('TV(2.0) Loss', 364.24323)], overall loss: -488.80413818359375
# Iteration: 15, named_losses: [('ActivationMax Loss', -883.6637),
#  ('L-6.0 Norm Loss', 0.5377727),
#  ('TV(2.0) Loss', 387.2218)], overall loss: -495.90411376953125
# Iteration: 16, named_losses: [('ActivationMax Loss', -907.417),
#  ('L-6.0 Norm Loss', 0.5563429),
#  ('TV(2.0) Loss', 396.1031)], overall loss: -510.757568359375
# Iteration: 17, named_losses: [('ActivationMax Loss', -928.2292),
#  ('L-6.0 Norm Loss', 0.579226),
#  ('TV(2.0) Loss', 408.014)], overall loss: -519.635986328125
# Iteration: 18, named_losses: [('ActivationMax Loss', -952.0479),
#  ('L-6.0 Norm Loss', 0.59669685),
#  ('TV(2.0) Loss', 421.3306)], overall loss: -530.12060546875
# Iteration: 19, named_losses: [('ActivationMax Loss', -972.1383),
#  ('L-6.0 Norm Loss', 0.6156629),
#  ('TV(2.0) Loss', 429.877)], overall loss: -541.6456298828125
# Iteration: 20, named_losses: [('ActivationMax Loss', -990.42615),
#  ('L-6.0 Norm Loss', 0.6328869),
#  ('TV(2.0) Loss', 442.99838)], overall loss: -546.794921875
# Iteration: 21, named_losses: [('ActivationMax Loss', -1001.88696),
#  ('L-6.0 Norm Loss', 0.64887035),
#  ('TV(2.0) Loss', 444.82117)], overall loss: -556.4169311523438
# Iteration: 22, named_losses: [('ActivationMax Loss', -1021.10236),
#  ('L-6.0 Norm Loss', 0.6656195),
#  ('TV(2.0) Loss', 458.02)], overall loss: -562.416748046875
# Iteration: 23, named_losses: [('ActivationMax Loss', -1034.3259),
#  ('L-6.0 Norm Loss', 0.679358),
#  ('TV(2.0) Loss', 460.38632)], overall loss: -573.26025390625
# Iteration: 24, named_losses: [('ActivationMax Loss', -1050.3955),
#  ('L-6.0 Norm Loss', 0.69454616),
#  ('TV(2.0) Loss', 467.91293)], overall loss: -581.7879638671875
# Iteration: 25, named_losses: [('ActivationMax Loss', -1059.14),
#  ('L-6.0 Norm Loss', 0.7104128),
#  ('TV(2.0) Loss', 470.05585)], overall loss: -588.3737182617188
# Iteration: 26, named_losses: [('ActivationMax Loss', -1076.5146),
#  ('L-6.0 Norm Loss', 0.7235949),
#  ('TV(2.0) Loss', 479.96417)], overall loss: -595.8268432617188
# Iteration: 27, named_losses: [('ActivationMax Loss', -1087.7559),
#  ('L-6.0 Norm Loss', 0.7401594),
#  ('TV(2.0) Loss', 483.80823)], overall loss: -603.20751953125
# Iteration: 28, named_losses: [('ActivationMax Loss', -1102.6786),
#  ('L-6.0 Norm Loss', 0.7534127),
#  ('TV(2.0) Loss', 492.26636)], overall loss: -609.6588134765625
# Iteration: 29, named_losses: [('ActivationMax Loss', -1114.335),
#  ('L-6.0 Norm Loss', 0.77129936),
#  ('TV(2.0) Loss', 497.20013)], overall loss: -616.3635864257812
# Iteration: 30, named_losses: [('ActivationMax Loss', -1131.6892),
#  ('L-6.0 Norm Loss', 0.78404284),
#  ('TV(2.0) Loss', 508.7041)], overall loss: -622.2010498046875
# Iteration: 31, named_losses: [('ActivationMax Loss', -1146.7081),
#  ('L-6.0 Norm Loss', 0.8009617),
#  ('TV(2.0) Loss', 516.6851)], overall loss: -629.2221069335938
# Iteration: 32, named_losses: [('ActivationMax Loss', -1155.5343),
#  ('L-6.0 Norm Loss', 0.81380266),
#  ('TV(2.0) Loss', 519.8994)], overall loss: -634.821044921875
# Iteration: 33, named_losses: [('ActivationMax Loss', -1167.8167),
#  ('L-6.0 Norm Loss', 0.8289721),
#  ('TV(2.0) Loss', 526.45386)], overall loss: -640.5338134765625
# Iteration: 34, named_losses: [('ActivationMax Loss', -1181.7169),
#  ('L-6.0 Norm Loss', 0.8421314),
#  ('TV(2.0) Loss', 537.8037)], overall loss: -643.071044921875
# Iteration: 35, named_losses: [('ActivationMax Loss', -1190.2129),
#  ('L-6.0 Norm Loss', 0.8558652),
#  ('TV(2.0) Loss', 543.89795)], overall loss: -645.4591064453125
# Iteration: 36, named_losses: [('ActivationMax Loss', -1202.5177),
#  ('L-6.0 Norm Loss', 0.8660175),
#  ('TV(2.0) Loss', 551.7114)], overall loss: -649.9403076171875
# Iteration: 37, named_losses: [('ActivationMax Loss', -1209.4768),
#  ('L-6.0 Norm Loss', 0.8763462),
#  ('TV(2.0) Loss', 555.1337)], overall loss: -653.4667358398438
# Iteration: 38, named_losses: [('ActivationMax Loss', -1221.5139),
#  ('L-6.0 Norm Loss', 0.8878622),
#  ('TV(2.0) Loss', 564.85486)], overall loss: -655.771240234375
# Iteration: 39, named_losses: [('ActivationMax Loss', -1225.055),
#  ('L-6.0 Norm Loss', 0.89836556),
#  ('TV(2.0) Loss', 564.26886)], overall loss: -659.8878784179688
# Iteration: 40, named_losses: [('ActivationMax Loss', -1236.6083),
#  ('L-6.0 Norm Loss', 0.90828484),
#  ('TV(2.0) Loss', 573.73456)], overall loss: -661.9653930664062
# Iteration: 41, named_losses: [('ActivationMax Loss', -1237.9534),
#  ('L-6.0 Norm Loss', 0.91909534),
#  ('TV(2.0) Loss', 571.15094)], overall loss: -665.8833618164062
# Iteration: 42, named_losses: [('ActivationMax Loss', -1250.7786),
#  ('L-6.0 Norm Loss', 0.93027425),
#  ('TV(2.0) Loss', 581.5232)], overall loss: -668.3250732421875
# Iteration: 43, named_losses: [('ActivationMax Loss', -1255.4598),
#  ('L-6.0 Norm Loss', 0.9412869),
#  ('TV(2.0) Loss', 583.579)], overall loss: -670.9395751953125
# Iteration: 44, named_losses: [('ActivationMax Loss', -1266.1127),
#  ('L-6.0 Norm Loss', 0.95096266),
#  ('TV(2.0) Loss', 592.51215)], overall loss: -672.6495971679688
# Iteration: 45, named_losses: [('ActivationMax Loss', -1266.3778),
#  ('L-6.0 Norm Loss', 0.9618054),
#  ('TV(2.0) Loss', 590.1463)], overall loss: -675.2697143554688
# Iteration: 46, named_losses: [('ActivationMax Loss', -1278.2731),
#  ('L-6.0 Norm Loss', 0.97149765),
#  ('TV(2.0) Loss', 600.6824)], overall loss: -676.619140625
# Iteration: 47, named_losses: [('ActivationMax Loss', -1277.9767),
#  ('L-6.0 Norm Loss', 0.9797644),
#  ('TV(2.0) Loss', 597.54016)], overall loss: -679.456787109375
# Iteration: 48, named_losses: [('ActivationMax Loss', -1289.8143),
#  ('L-6.0 Norm Loss', 0.9887216),
#  ('TV(2.0) Loss', 607.52136)], overall loss: -681.30419921875
# Iteration: 49, named_losses: [('ActivationMax Loss', -1289.9209),
#  ('L-6.0 Norm Loss', 0.9973462),
#  ('TV(2.0) Loss', 605.3113)], overall loss: -683.6123046875
# Iteration: 50, named_losses: [('ActivationMax Loss', -1301.765),
#  ('L-6.0 Norm Loss', 1.0064942),
#  ('TV(2.0) Loss', 615.4314)], overall loss: -685.3271484375
# Iteration: 51, named_losses: [('ActivationMax Loss', -1300.1548),
#  ('L-6.0 Norm Loss', 1.0154788),
#  ('TV(2.0) Loss', 611.69977)], overall loss: -687.4395141601562
# Iteration: 52, named_losses: [('ActivationMax Loss', -1311.5372),
#  ('L-6.0 Norm Loss', 1.0237406),
#  ('TV(2.0) Loss', 620.9679)], overall loss: -689.545654296875
# Iteration: 53, named_losses: [('ActivationMax Loss', -1309.5685),
#  ('L-6.0 Norm Loss', 1.0306021),
#  ('TV(2.0) Loss', 616.1904)], overall loss: -692.347412109375
# Iteration: 54, named_losses: [('ActivationMax Loss', -1320.6332),
#  ('L-6.0 Norm Loss', 1.0379485),
#  ('TV(2.0) Loss', 625.0269)], overall loss: -694.5682983398438
# Iteration: 55, named_losses: [('ActivationMax Loss', -1316.3137),
#  ('L-6.0 Norm Loss', 1.0457754),
#  ('TV(2.0) Loss', 620.08685)], overall loss: -695.1810913085938
# Iteration: 56, named_losses: [('ActivationMax Loss', -1330.9879),
#  ('L-6.0 Norm Loss', 1.0538912),
#  ('TV(2.0) Loss', 632.0139)], overall loss: -697.920166015625
# Iteration: 57, named_losses: [('ActivationMax Loss', -1323.6132),
#  ('L-6.0 Norm Loss', 1.0589746),
#  ('TV(2.0) Loss', 622.69806)], overall loss: -699.8561401367188
# Iteration: 58, named_losses: [('ActivationMax Loss', -1337.1724),
#  ('L-6.0 Norm Loss', 1.0663234),
#  ('TV(2.0) Loss', 633.41864)], overall loss: -702.6874389648438
# Iteration: 59, named_losses: [('ActivationMax Loss', -1331.879),
#  ('L-6.0 Norm Loss', 1.0720199),
#  ('TV(2.0) Loss', 626.2367)], overall loss: -704.5703125
# Iteration: 60, named_losses: [('ActivationMax Loss', -1339.2845),
#  ('L-6.0 Norm Loss', 1.0804052),
#  ('TV(2.0) Loss', 630.58203)], overall loss: -707.6220703125
# Iteration: 61, named_losses: [('ActivationMax Loss', -1339.4922),
#  ('L-6.0 Norm Loss', 1.0905097),
#  ('TV(2.0) Loss', 629.11145)], overall loss: -709.290283203125
# Iteration: 62, named_losses: [('ActivationMax Loss', -1347.6843),
#  ('L-6.0 Norm Loss', 1.0974964),
#  ('TV(2.0) Loss', 635.8421)], overall loss: -710.7446899414062
# Iteration: 63, named_losses: [('ActivationMax Loss', -1344.4795),
#  ('L-6.0 Norm Loss', 1.1030114),
#  ('TV(2.0) Loss', 630.641)], overall loss: -712.7354736328125
# Iteration: 64, named_losses: [('ActivationMax Loss', -1353.5453),
#  ('L-6.0 Norm Loss', 1.1102655),
#  ('TV(2.0) Loss', 638.10583)], overall loss: -714.3292236328125
# Iteration: 65, named_losses: [('ActivationMax Loss', -1351.41),
#  ('L-6.0 Norm Loss', 1.1183019),
#  ('TV(2.0) Loss', 632.7619)], overall loss: -717.5298461914062
# Iteration: 66, named_losses: [('ActivationMax Loss', -1360.3033),
#  ('L-6.0 Norm Loss', 1.1212417),
#  ('TV(2.0) Loss', 640.4804)], overall loss: -718.7017211914062
# Iteration: 67, named_losses: [('ActivationMax Loss', -1360.7976),
#  ('L-6.0 Norm Loss', 1.1270438),
#  ('TV(2.0) Loss', 639.1951)], overall loss: -720.4754028320312
# Iteration: 68, named_losses: [('ActivationMax Loss', -1364.1449),
#  ('L-6.0 Norm Loss', 1.1351146),
#  ('TV(2.0) Loss', 639.4208)], overall loss: -723.5889892578125
# Iteration: 69, named_losses: [('ActivationMax Loss', -1369.2688),
#  ('L-6.0 Norm Loss', 1.1409991),
#  ('TV(2.0) Loss', 643.0625)], overall loss: -725.0653076171875
# Iteration: 70, named_losses: [('ActivationMax Loss', -1372.4766),
#  ('L-6.0 Norm Loss', 1.1485612),
#  ('TV(2.0) Loss', 642.28735)], overall loss: -729.0406494140625
# Iteration: 71, named_losses: [('ActivationMax Loss', -1380.6813),
#  ('L-6.0 Norm Loss', 1.1537211),
#  ('TV(2.0) Loss', 649.1205)], overall loss: -730.4071044921875
# Iteration: 72, named_losses: [('ActivationMax Loss', -1383.8418),
#  ('L-6.0 Norm Loss', 1.1586269),
#  ('TV(2.0) Loss', 649.52936)], overall loss: -733.1538696289062
# Iteration: 73, named_losses: [('ActivationMax Loss', -1386.1376),
#  ('L-6.0 Norm Loss', 1.1656183),
#  ('TV(2.0) Loss', 649.7132)], overall loss: -735.2587280273438
# Iteration: 74, named_losses: [('ActivationMax Loss', -1392.708),
#  ('L-6.0 Norm Loss', 1.1704657),
#  ('TV(2.0) Loss', 655.65375)], overall loss: -735.8838500976562
# Iteration: 75, named_losses: [('ActivationMax Loss', -1393.942),
#  ('L-6.0 Norm Loss', 1.1791731),
#  ('TV(2.0) Loss', 655.8298)], overall loss: -736.9330444335938
# Iteration: 76, named_losses: [('ActivationMax Loss', -1393.6503),
#  ('L-6.0 Norm Loss', 1.1869074),
#  ('TV(2.0) Loss', 651.9629)], overall loss: -740.50048828125
# Iteration: 77, named_losses: [('ActivationMax Loss', -1401.3741),
#  ('L-6.0 Norm Loss', 1.1914862),
#  ('TV(2.0) Loss', 657.51715)], overall loss: -742.6654663085938
# Iteration: 78, named_losses: [('ActivationMax Loss', -1406.7512),
#  ('L-6.0 Norm Loss', 1.1984617),
#  ('TV(2.0) Loss', 660.8822)], overall loss: -744.6705322265625
# Iteration: 79, named_losses: [('ActivationMax Loss', -1404.8087),
#  ('L-6.0 Norm Loss', 1.206514),
#  ('TV(2.0) Loss', 657.28723)], overall loss: -746.31494140625
# Iteration: 80, named_losses: [('ActivationMax Loss', -1416.6132),
#  ('L-6.0 Norm Loss', 1.2127321),
#  ('TV(2.0) Loss', 667.21643)], overall loss: -748.1839599609375
# Iteration: 81, named_losses: [('ActivationMax Loss', -1421.1543),
#  ('L-6.0 Norm Loss', 1.2166195),
#  ('TV(2.0) Loss', 670.2733)], overall loss: -749.664306640625
# Iteration: 82, named_losses: [('ActivationMax Loss', -1424.3278),
#  ('L-6.0 Norm Loss', 1.2244998),
#  ('TV(2.0) Loss', 670.8263)], overall loss: -752.2769775390625
# Iteration: 83, named_losses: [('ActivationMax Loss', -1429.3124),
#  ('L-6.0 Norm Loss', 1.2283039),
#  ('TV(2.0) Loss', 676.60345)], overall loss: -751.4806518554688
# Iteration: 84, named_losses: [('ActivationMax Loss', -1424.1338),
#  ('L-6.0 Norm Loss', 1.2358996),
#  ('TV(2.0) Loss', 669.748)], overall loss: -753.1499633789062
# Iteration: 85, named_losses: [('ActivationMax Loss', -1434.3925),
#  ('L-6.0 Norm Loss', 1.2423978),
#  ('TV(2.0) Loss', 678.21344)], overall loss: -754.9365844726562
# Iteration: 86, named_losses: [('ActivationMax Loss', -1431.6915),
#  ('L-6.0 Norm Loss', 1.249146),
#  ('TV(2.0) Loss', 674.583)], overall loss: -755.859375
# Iteration: 87, named_losses: [('ActivationMax Loss', -1440.4209),
#  ('L-6.0 Norm Loss', 1.253233),
#  ('TV(2.0) Loss', 681.9069)], overall loss: -757.2608032226562
# Iteration: 88, named_losses: [('ActivationMax Loss', -1441.6838),
#  ('L-6.0 Norm Loss', 1.2578213),
#  ('TV(2.0) Loss', 682.44507)], overall loss: -757.98095703125
# Iteration: 89, named_losses: [('ActivationMax Loss', -1444.2775),
#  ('L-6.0 Norm Loss', 1.2632285),
#  ('TV(2.0) Loss', 683.95154)], overall loss: -759.062744140625
# Iteration: 90, named_losses: [('ActivationMax Loss', -1444.1677),
#  ('L-6.0 Norm Loss', 1.2730832),
#  ('TV(2.0) Loss', 683.93414)], overall loss: -758.9605102539062
# Iteration: 91, named_losses: [('ActivationMax Loss', -1450.4155),
#  ('L-6.0 Norm Loss', 1.2756639),
#  ('TV(2.0) Loss', 688.36414)], overall loss: -760.7757568359375
# Iteration: 92, named_losses: [('ActivationMax Loss', -1452.0817),
#  ('L-6.0 Norm Loss', 1.286433),
#  ('TV(2.0) Loss', 690.3937)], overall loss: -760.401611328125
# Iteration: 93, named_losses: [('ActivationMax Loss', -1453.4103),
#  ('L-6.0 Norm Loss', 1.2890211),
#  ('TV(2.0) Loss', 689.10297)], overall loss: -763.0182495117188
# Iteration: 94, named_losses: [('ActivationMax Loss', -1461.0963),
#  ('L-6.0 Norm Loss', 1.2931633),
#  ('TV(2.0) Loss', 697.1956)], overall loss: -762.6074829101562
# Iteration: 95, named_losses: [('ActivationMax Loss', -1456.0863),
#  ('L-6.0 Norm Loss', 1.2987555),
#  ('TV(2.0) Loss', 690.1918)], overall loss: -764.5958251953125
# Iteration: 96, named_losses: [('ActivationMax Loss', -1469.6613),
#  ('L-6.0 Norm Loss', 1.3037597),
#  ('TV(2.0) Loss', 703.0046)], overall loss: -765.3529663085938
# Iteration: 97, named_losses: [('ActivationMax Loss', -1469.1371),
#  ('L-6.0 Norm Loss', 1.3101673),
#  ('TV(2.0) Loss', 701.6084)], overall loss: -766.218505859375
# Iteration: 98, named_losses: [('ActivationMax Loss', -1474.0115),
#  ('L-6.0 Norm Loss', 1.3154222),
#  ('TV(2.0) Loss', 706.274)], overall loss: -766.4220581054688
# Iteration: 99, named_losses: [('ActivationMax Loss', -1464.5646),
#  ('L-6.0 Norm Loss', 1.3242402),
#  ('TV(2.0) Loss', 694.7894)], overall loss: -768.450927734375
# Iteration: 100, named_losses: [('ActivationMax Loss', -1480.2303),
#  ('L-6.0 Norm Loss', 1.3236183),
#  ('TV(2.0) Loss', 709.20386)], overall loss: -769.702880859375
# Iteration: 101, named_losses: [('ActivationMax Loss', -1477.435),
#  ('L-6.0 Norm Loss', 1.3297223),
#  ('TV(2.0) Loss', 705.4097)], overall loss: -770.6956176757812
# Iteration: 102, named_losses: [('ActivationMax Loss', -1489.8009),
#  ('L-6.0 Norm Loss', 1.3364304),
#  ('TV(2.0) Loss', 715.7267)], overall loss: -772.73779296875
# Iteration: 103, named_losses: [('ActivationMax Loss', -1486.3761),
#  ('L-6.0 Norm Loss', 1.3378136),
#  ('TV(2.0) Loss', 709.8056)], overall loss: -775.2327270507812
# Iteration: 104, named_losses: [('ActivationMax Loss', -1497.2656),
#  ('L-6.0 Norm Loss', 1.3452348),
#  ('TV(2.0) Loss', 720.7031)], overall loss: -775.21728515625
# Iteration: 105, named_losses: [('ActivationMax Loss', -1489.9579),
#  ('L-6.0 Norm Loss', 1.3459522),
#  ('TV(2.0) Loss', 712.50336)], overall loss: -776.1085815429688
# Iteration: 106, named_losses: [('ActivationMax Loss', -1500.7106),
#  ('L-6.0 Norm Loss', 1.3535802),
#  ('TV(2.0) Loss', 721.0439)], overall loss: -778.3130493164062
# Iteration: 107, named_losses: [('ActivationMax Loss', -1502.738),
#  ('L-6.0 Norm Loss', 1.3538368),
#  ('TV(2.0) Loss', 722.58496)], overall loss: -778.7991943359375
# Iteration: 108, named_losses: [('ActivationMax Loss', -1500.0614),
#  ('L-6.0 Norm Loss', 1.3613418),
#  ('TV(2.0) Loss', 717.4758)], overall loss: -781.2242431640625
# Iteration: 109, named_losses: [('ActivationMax Loss', -1509.7743),
#  ('L-6.0 Norm Loss', 1.3635533),
#  ('TV(2.0) Loss', 730.0982)], overall loss: -778.3125610351562
# Iteration: 110, named_losses: [('ActivationMax Loss', -1512.9753),
#  ('L-6.0 Norm Loss', 1.3700427),
#  ('TV(2.0) Loss', 728.55383)], overall loss: -783.051513671875
# Iteration: 111, named_losses: [('ActivationMax Loss', -1513.7333),
#  ('L-6.0 Norm Loss', 1.3685946),
#  ('TV(2.0) Loss', 731.1153)], overall loss: -781.2493286132812
# Iteration: 112, named_losses: [('ActivationMax Loss', -1515.4276),
#  ('L-6.0 Norm Loss', 1.3778877),
#  ('TV(2.0) Loss', 729.7051)], overall loss: -784.3446044921875
# Iteration: 113, named_losses: [('ActivationMax Loss', -1521.114),
#  ('L-6.0 Norm Loss', 1.3795346),
#  ('TV(2.0) Loss', 735.8215)], overall loss: -783.9130249023438
# Iteration: 114, named_losses: [('ActivationMax Loss', -1514.5875),
#  ('L-6.0 Norm Loss', 1.3813491),
#  ('TV(2.0) Loss', 728.0176)], overall loss: -785.1885986328125
# Iteration: 115, named_losses: [('ActivationMax Loss', -1522.5798),
#  ('L-6.0 Norm Loss', 1.3856214),
#  ('TV(2.0) Loss', 735.5371)], overall loss: -785.6571044921875
# Iteration: 116, named_losses: [('ActivationMax Loss', -1518.5563),
#  ('L-6.0 Norm Loss', 1.39299),
#  ('TV(2.0) Loss', 729.1799)], overall loss: -787.9834594726562
# Iteration: 117, named_losses: [('ActivationMax Loss', -1527.7235),
#  ('L-6.0 Norm Loss', 1.3963848),
#  ('TV(2.0) Loss', 739.468)], overall loss: -786.859130859375
# Iteration: 118, named_losses: [('ActivationMax Loss', -1532.3365),
#  ('L-6.0 Norm Loss', 1.3996261),
#  ('TV(2.0) Loss', 743.06476)], overall loss: -787.8721313476562
# Iteration: 119, named_losses: [('ActivationMax Loss', -1530.9396),
#  ('L-6.0 Norm Loss', 1.4045589),
#  ('TV(2.0) Loss', 741.3931)], overall loss: -788.1419067382812
# Iteration: 120, named_losses: [('ActivationMax Loss', -1533.1838),
#  ('L-6.0 Norm Loss', 1.4061955),
#  ('TV(2.0) Loss', 743.73914)], overall loss: -788.0384521484375
# Iteration: 121, named_losses: [('ActivationMax Loss', -1534.7197),
#  ('L-6.0 Norm Loss', 1.4107527),
#  ('TV(2.0) Loss', 744.35376)], overall loss: -788.9552001953125
# Iteration: 122, named_losses: [('ActivationMax Loss', -1542.3851),
#  ('L-6.0 Norm Loss', 1.4154775),
#  ('TV(2.0) Loss', 751.8224)], overall loss: -789.147216796875
# Iteration: 123, named_losses: [('ActivationMax Loss', -1540.1287),
#  ('L-6.0 Norm Loss', 1.4185473),
#  ('TV(2.0) Loss', 748.59155)], overall loss: -790.1185302734375
# Iteration: 124, named_losses: [('ActivationMax Loss', -1544.3755),
#  ('L-6.0 Norm Loss', 1.4177613),
#  ('TV(2.0) Loss', 753.4786)], overall loss: -789.4791870117188
# Iteration: 125, named_losses: [('ActivationMax Loss', -1548.8806),
#  ('L-6.0 Norm Loss', 1.4218124),
#  ('TV(2.0) Loss', 754.74066)], overall loss: -792.7182006835938
# Iteration: 126, named_losses: [('ActivationMax Loss', -1541.8019),
#  ('L-6.0 Norm Loss', 1.4281406),
#  ('TV(2.0) Loss', 749.45013)], overall loss: -790.9236450195312
# Iteration: 127, named_losses: [('ActivationMax Loss', -1548.1705),
#  ('L-6.0 Norm Loss', 1.4278618),
#  ('TV(2.0) Loss', 753.70416)], overall loss: -793.0385131835938
# Iteration: 128, named_losses: [('ActivationMax Loss', -1542.4531),
#  ('L-6.0 Norm Loss', 1.4320211),
#  ('TV(2.0) Loss', 749.7186)], overall loss: -791.302490234375
# Iteration: 129, named_losses: [('ActivationMax Loss', -1549.4109),
#  ('L-6.0 Norm Loss', 1.4349205),
#  ('TV(2.0) Loss', 753.8552)], overall loss: -794.1207275390625
# Iteration: 130, named_losses: [('ActivationMax Loss', -1550.5577),
#  ('L-6.0 Norm Loss', 1.4371829),
#  ('TV(2.0) Loss', 756.9778)], overall loss: -792.142822265625
# Iteration: 131, named_losses: [('ActivationMax Loss', -1548.6613),
#  ('L-6.0 Norm Loss', 1.4412276),
#  ('TV(2.0) Loss', 751.6117)], overall loss: -795.6082763671875
# Iteration: 132, named_losses: [('ActivationMax Loss', -1554.0396),
#  ('L-6.0 Norm Loss', 1.4435965),
#  ('TV(2.0) Loss', 760.4212)], overall loss: -792.1747436523438
# Iteration: 133, named_losses: [('ActivationMax Loss', -1548.8217),
#  ('L-6.0 Norm Loss', 1.4521048),
#  ('TV(2.0) Loss', 751.81555)], overall loss: -795.553955078125
# Iteration: 134, named_losses: [('ActivationMax Loss', -1556.6844),
#  ('L-6.0 Norm Loss', 1.4503019),
#  ('TV(2.0) Loss', 761.93256)], overall loss: -793.3015747070312
# Iteration: 135, named_losses: [('ActivationMax Loss', -1556.0454),
#  ('L-6.0 Norm Loss', 1.4510188),
#  ('TV(2.0) Loss', 756.96277)], overall loss: -797.631591796875
# Iteration: 136, named_losses: [('ActivationMax Loss', -1556.8772),
#  ('L-6.0 Norm Loss', 1.4520947),
#  ('TV(2.0) Loss', 761.7556)], overall loss: -793.66943359375
# Iteration: 137, named_losses: [('ActivationMax Loss', -1550.4979),
#  ('L-6.0 Norm Loss', 1.4599524),
#  ('TV(2.0) Loss', 750.5474)], overall loss: -798.4905395507812
# Iteration: 138, named_losses: [('ActivationMax Loss', -1564.9866),
#  ('L-6.0 Norm Loss', 1.4616419),
#  ('TV(2.0) Loss', 768.0923)], overall loss: -795.4326171875
# Iteration: 139, named_losses: [('ActivationMax Loss', -1564.6007),
#  ('L-6.0 Norm Loss', 1.4646227),
#  ('TV(2.0) Loss', 765.3531)], overall loss: -797.7830200195312
# Iteration: 140, named_losses: [('ActivationMax Loss', -1558.4448),
#  ('L-6.0 Norm Loss', 1.4696729),
#  ('TV(2.0) Loss', 759.68616)], overall loss: -797.2889404296875
# Iteration: 141, named_losses: [('ActivationMax Loss', -1561.642),
#  ('L-6.0 Norm Loss', 1.4727815),
#  ('TV(2.0) Loss', 761.8036)], overall loss: -798.3656005859375
# Iteration: 142, named_losses: [('ActivationMax Loss', -1564.7352),
#  ('L-6.0 Norm Loss', 1.4749259),
#  ('TV(2.0) Loss', 766.26794)], overall loss: -796.9923095703125
# Iteration: 143, named_losses: [('ActivationMax Loss', -1563.2587),
#  ('L-6.0 Norm Loss', 1.4789414),
#  ('TV(2.0) Loss', 762.89777)], overall loss: -798.8820190429688
# Iteration: 144, named_losses: [('ActivationMax Loss', -1567.8727),
#  ('L-6.0 Norm Loss', 1.4794571),
#  ('TV(2.0) Loss', 767.5165)], overall loss: -798.876708984375
# Iteration: 145, named_losses: [('ActivationMax Loss', -1573.1412),
#  ('L-6.0 Norm Loss', 1.4838871),
#  ('TV(2.0) Loss', 774.9709)], overall loss: -796.6864624023438
# Iteration: 146, named_losses: [('ActivationMax Loss', -1565.2709),
#  ('L-6.0 Norm Loss', 1.4880794),
#  ('TV(2.0) Loss', 764.6983)], overall loss: -799.0845336914062
# Iteration: 147, named_losses: [('ActivationMax Loss', -1571.9664),
#  ('L-6.0 Norm Loss', 1.4895177),
#  ('TV(2.0) Loss', 773.1232)], overall loss: -797.3536987304688
# Iteration: 148, named_losses: [('ActivationMax Loss', -1576.9822),
#  ('L-6.0 Norm Loss', 1.4908637),
#  ('TV(2.0) Loss', 776.2816)], overall loss: -799.209716796875
# Iteration: 149, named_losses: [('ActivationMax Loss', -1571.5204),
#  ('L-6.0 Norm Loss', 1.4945376),
#  ('TV(2.0) Loss', 771.2155)], overall loss: -798.8103637695312
# Iteration: 150, named_losses: [('ActivationMax Loss', -1577.2096),
#  ('L-6.0 Norm Loss', 1.493442),
#  ('TV(2.0) Loss', 775.09015)], overall loss: -800.6260375976562
# Iteration: 151, named_losses: [('ActivationMax Loss', -1575.5963),
#  ('L-6.0 Norm Loss', 1.4960767),
#  ('TV(2.0) Loss', 775.8942)], overall loss: -798.2059936523438
# Iteration: 152, named_losses: [('ActivationMax Loss', -1569.0465),
#  ('L-6.0 Norm Loss', 1.5020758),
#  ('TV(2.0) Loss', 767.009)], overall loss: -800.5354614257812
# Iteration: 153, named_losses: [('ActivationMax Loss', -1575.062),
#  ('L-6.0 Norm Loss', 1.5018942),
#  ('TV(2.0) Loss', 773.53424)], overall loss: -800.0258178710938
# Iteration: 154, named_losses: [('ActivationMax Loss', -1579.6713),
#  ('L-6.0 Norm Loss', 1.5084771),
#  ('TV(2.0) Loss', 778.8239)], overall loss: -799.3389282226562
# Iteration: 155, named_losses: [('ActivationMax Loss', -1580.9031),
#  ('L-6.0 Norm Loss', 1.508867),
#  ('TV(2.0) Loss', 778.0949)], overall loss: -801.2992553710938
# Iteration: 156, named_losses: [('ActivationMax Loss', -1572.9932),
#  ('L-6.0 Norm Loss', 1.5162144),
#  ('TV(2.0) Loss', 772.26666)], overall loss: -799.2102661132812
# Iteration: 157, named_losses: [('ActivationMax Loss', -1581.7976),
#  ('L-6.0 Norm Loss', 1.515384),
#  ('TV(2.0) Loss', 777.653)], overall loss: -802.6292114257812
# Iteration: 158, named_losses: [('ActivationMax Loss', -1579.2924),
#  ('L-6.0 Norm Loss', 1.5202008),
#  ('TV(2.0) Loss', 778.58966)], overall loss: -799.1825561523438
# Iteration: 159, named_losses: [('ActivationMax Loss', -1586.7274),
#  ('L-6.0 Norm Loss', 1.5213579),
#  ('TV(2.0) Loss', 782.1994)], overall loss: -803.0066528320312
# Iteration: 160, named_losses: [('ActivationMax Loss', -1576.6581),
#  ('L-6.0 Norm Loss', 1.5252287),
#  ('TV(2.0) Loss', 774.34686)], overall loss: -800.7859497070312
# Iteration: 161, named_losses: [('ActivationMax Loss', -1586.445),
#  ('L-6.0 Norm Loss', 1.5258565),
#  ('TV(2.0) Loss', 780.90674)], overall loss: -804.0123291015625
# Iteration: 162, named_losses: [('ActivationMax Loss', -1586.1442),
#  ('L-6.0 Norm Loss', 1.5293593),
#  ('TV(2.0) Loss', 783.4665)], overall loss: -801.1482543945312
# Iteration: 163, named_losses: [('ActivationMax Loss', -1586.106),
#  ('L-6.0 Norm Loss', 1.5344214),
#  ('TV(2.0) Loss', 779.21783)], overall loss: -805.3536987304688
# Iteration: 164, named_losses: [('ActivationMax Loss', -1584.7965),
#  ('L-6.0 Norm Loss', 1.5336363),
#  ('TV(2.0) Loss', 781.88257)], overall loss: -801.3802490234375
# Iteration: 165, named_losses: [('ActivationMax Loss', -1579.4204),
#  ('L-6.0 Norm Loss', 1.5368665),
#  ('TV(2.0) Loss', 772.6563)], overall loss: -805.2272338867188
# Iteration: 166, named_losses: [('ActivationMax Loss', -1584.5814),
#  ('L-6.0 Norm Loss', 1.5378358),
#  ('TV(2.0) Loss', 780.75885)], overall loss: -802.2847290039062
# Iteration: 167, named_losses: [('ActivationMax Loss', -1587.9773),
#  ('L-6.0 Norm Loss', 1.5380099),
#  ('TV(2.0) Loss', 781.4745)], overall loss: -804.96484375
# Iteration: 168, named_losses: [('ActivationMax Loss', -1582.7662),
#  ('L-6.0 Norm Loss', 1.5446403),
#  ('TV(2.0) Loss', 778.4843)], overall loss: -802.7372436523438
# Iteration: 169, named_losses: [('ActivationMax Loss', -1590.6593),
#  ('L-6.0 Norm Loss', 1.5446361),
#  ('TV(2.0) Loss', 782.56757)], overall loss: -806.5470581054688
# Iteration: 170, named_losses: [('ActivationMax Loss', -1584.3704),
#  ('L-6.0 Norm Loss', 1.5496657),
#  ('TV(2.0) Loss', 779.7103)], overall loss: -803.1103515625
# Iteration: 171, named_losses: [('ActivationMax Loss', -1592.6343),
#  ('L-6.0 Norm Loss', 1.5489364),
#  ('TV(2.0) Loss', 783.9854)], overall loss: -807.0999145507812
# Iteration: 172, named_losses: [('ActivationMax Loss', -1593.1824),
#  ('L-6.0 Norm Loss', 1.554164),
#  ('TV(2.0) Loss', 788.2465)], overall loss: -803.3816528320312
# Iteration: 173, named_losses: [('ActivationMax Loss', -1585.6063),
#  ('L-6.0 Norm Loss', 1.5585326),
#  ('TV(2.0) Loss', 775.9768)], overall loss: -808.071044921875
# Iteration: 174, named_losses: [('ActivationMax Loss', -1595.4073),
#  ('L-6.0 Norm Loss', 1.5551871),
#  ('TV(2.0) Loss', 788.7608)], overall loss: -805.0913696289062
# Iteration: 175, named_losses: [('ActivationMax Loss', -1588.7848),
#  ('L-6.0 Norm Loss', 1.560819),
#  ('TV(2.0) Loss', 779.9169)], overall loss: -807.30712890625
# Iteration: 176, named_losses: [('ActivationMax Loss', -1599.9589),
#  ('L-6.0 Norm Loss', 1.563156),
#  ('TV(2.0) Loss', 793.52704)], overall loss: -804.8687133789062
# Iteration: 177, named_losses: [('ActivationMax Loss', -1592.1223),
#  ('L-6.0 Norm Loss', 1.5651888),
#  ('TV(2.0) Loss', 783.73114)], overall loss: -806.8259887695312
# Iteration: 178, named_losses: [('ActivationMax Loss', -1599.7545),
#  ('L-6.0 Norm Loss', 1.569362),
#  ('TV(2.0) Loss', 791.72876)], overall loss: -806.4564208984375
# Iteration: 179, named_losses: [('ActivationMax Loss', -1596.459),
#  ('L-6.0 Norm Loss', 1.5695497),
#  ('TV(2.0) Loss', 788.101)], overall loss: -806.7883911132812
# Iteration: 180, named_losses: [('ActivationMax Loss', -1591.6954),
#  ('L-6.0 Norm Loss', 1.5770199),
#  ('TV(2.0) Loss', 783.9641)], overall loss: -806.154296875
# Iteration: 181, named_losses: [('ActivationMax Loss', -1597.4297),
#  ('L-6.0 Norm Loss', 1.5758559),
#  ('TV(2.0) Loss', 788.2333)], overall loss: -807.62060546875
# Iteration: 182, named_losses: [('ActivationMax Loss', -1601.6276),
#  ('L-6.0 Norm Loss', 1.5769695),
#  ('TV(2.0) Loss', 793.5581)], overall loss: -806.492431640625
# Iteration: 183, named_losses: [('ActivationMax Loss', -1598.7323),
#  ('L-6.0 Norm Loss', 1.580553),
#  ('TV(2.0) Loss', 789.557)], overall loss: -807.5947265625
# Iteration: 184, named_losses: [('ActivationMax Loss', -1602.017),
#  ('L-6.0 Norm Loss', 1.5826283),
#  ('TV(2.0) Loss', 793.2775)], overall loss: -807.1567993164062
# Iteration: 185, named_losses: [('ActivationMax Loss', -1595.1184),
#  ('L-6.0 Norm Loss', 1.5891019),
#  ('TV(2.0) Loss', 785.1312)], overall loss: -808.3980712890625
# Iteration: 186, named_losses: [('ActivationMax Loss', -1604.4156),
#  ('L-6.0 Norm Loss', 1.5891674),
#  ('TV(2.0) Loss', 795.8476)], overall loss: -806.9789428710938
# Iteration: 187, named_losses: [('ActivationMax Loss', -1604.685),
#  ('L-6.0 Norm Loss', 1.5896633),
#  ('TV(2.0) Loss', 794.86865)], overall loss: -808.2266845703125
# Iteration: 188, named_losses: [('ActivationMax Loss', -1602.7833),
#  ('L-6.0 Norm Loss', 1.590909),
#  ('TV(2.0) Loss', 793.82715)], overall loss: -807.365234375
# Iteration: 189, named_losses: [('ActivationMax Loss', -1603.8783),
#  ('L-6.0 Norm Loss', 1.5924313),
#  ('TV(2.0) Loss', 793.61804)], overall loss: -808.6678466796875
# Iteration: 190, named_losses: [('ActivationMax Loss', -1607.1191),
#  ('L-6.0 Norm Loss', 1.5959227),
#  ('TV(2.0) Loss', 798.8854)], overall loss: -806.6378173828125
# Iteration: 191, named_losses: [('ActivationMax Loss', -1600.6842),
#  ('L-6.0 Norm Loss', 1.6008908),
#  ('TV(2.0) Loss', 790.6548)], overall loss: -808.4285888671875
# Iteration: 192, named_losses: [('ActivationMax Loss', -1612.5408),
#  ('L-6.0 Norm Loss', 1.60076),
#  ('TV(2.0) Loss', 802.2114)], overall loss: -808.7286376953125
# Iteration: 193, named_losses: [('ActivationMax Loss', -1601.4252),
#  ('L-6.0 Norm Loss', 1.6025199),
#  ('TV(2.0) Loss', 791.1527)], overall loss: -808.669921875
# Iteration: 194, named_losses: [('ActivationMax Loss', -1611.7009),
#  ('L-6.0 Norm Loss', 1.602875),
#  ('TV(2.0) Loss', 801.8629)], overall loss: -808.235107421875
# Iteration: 195, named_losses: [('ActivationMax Loss', -1605.6755),
#  ('L-6.0 Norm Loss', 1.605282),
#  ('TV(2.0) Loss', 795.3041)], overall loss: -808.7662353515625
# Iteration: 196, named_losses: [('ActivationMax Loss', -1612.0033),
#  ('L-6.0 Norm Loss', 1.6067646),
#  ('TV(2.0) Loss', 801.4638)], overall loss: -808.9326782226562
# Iteration: 197, named_losses: [('ActivationMax Loss', -1600.9103),
#  ('L-6.0 Norm Loss', 1.6121354),
#  ('TV(2.0) Loss', 790.6623)], overall loss: -808.6358032226562
# Iteration: 198, named_losses: [('ActivationMax Loss', -1613.5995),
#  ('L-6.0 Norm Loss', 1.6115253),
#  ('TV(2.0) Loss', 802.0779)], overall loss: -809.9100341796875
# Iteration: 199, named_losses: [('ActivationMax Loss', -1614.8553),
#  ('L-6.0 Norm Loss', 1.6110597),
#  ('TV(2.0) Loss', 804.07324)], overall loss: -809.1710205078125
# Iteration: 200, named_losses: [('ActivationMax Loss', -1610.2892),
#  ('L-6.0 Norm Loss', 1.6151125),
#  ('TV(2.0) Loss', 798.9324)], overall loss: -809.74169921875

# %% [markdown]
# In this case, `ActivationMax Loss` is not bouncing bouncing around and converging? Perhaps we could get that loss to be lower by reducing weights of other losses that might be dominating the overall loss being minimized.
#
# The simplest way to tune these weights is to first start with `0.` weights for all regularization losses.

# %%
img = visualize_activation(model, layer_idx, filter_indices=filter_idx, input_range=(0., 1.), 
                           tv_weight=0., lp_norm_weight=0., verbose=True)
plt.imshow(img[..., 0])
# Out:
# Iteration: 1, named_losses: [('ActivationMax Loss', 0.16577047)], overall loss: 0.16577047109603882
# Iteration: 2, named_losses: [('ActivationMax Loss', -6.7661395)], overall loss: -6.766139507293701
# Iteration: 3, named_losses: [('ActivationMax Loss', -245.00949)], overall loss: -245.00949096679688
# Iteration: 4, named_losses: [('ActivationMax Loss', -490.43997)], overall loss: -490.4399719238281
# Iteration: 5, named_losses: [('ActivationMax Loss', -718.81964)], overall loss: -718.8196411132812
# Iteration: 6, named_losses: [('ActivationMax Loss', -917.9072)], overall loss: -917.9072265625
# Iteration: 7, named_losses: [('ActivationMax Loss', -1107.584)], overall loss: -1107.583984375
# Iteration: 8, named_losses: [('ActivationMax Loss', -1294.1914)], overall loss: -1294.19140625
# Iteration: 9, named_losses: [('ActivationMax Loss', -1466.9081)], overall loss: -1466.9080810546875
# Iteration: 10, named_losses: [('ActivationMax Loss', -1632.4164)], overall loss: -1632.4163818359375
# Iteration: 11, named_losses: [('ActivationMax Loss', -1790.805)], overall loss: -1790.8050537109375
# Iteration: 12, named_losses: [('ActivationMax Loss', -1942.0554)], overall loss: -1942.055419921875
# Iteration: 13, named_losses: [('ActivationMax Loss', -2089.2183)], overall loss: -2089.21826171875
# Iteration: 14, named_losses: [('ActivationMax Loss', -2232.4983)], overall loss: -2232.498291015625
# Iteration: 15, named_losses: [('ActivationMax Loss', -2370.4248)], overall loss: -2370.4248046875
# Iteration: 16, named_losses: [('ActivationMax Loss', -2504.041)], overall loss: -2504.041015625
# Iteration: 17, named_losses: [('ActivationMax Loss', -2636.2502)], overall loss: -2636.250244140625
# Iteration: 18, named_losses: [('ActivationMax Loss', -2766.6663)], overall loss: -2766.666259765625
# Iteration: 19, named_losses: [('ActivationMax Loss', -2890.839)], overall loss: -2890.839111328125
# Iteration: 20, named_losses: [('ActivationMax Loss', -3014.826)], overall loss: -3014.825927734375
# Iteration: 21, named_losses: [('ActivationMax Loss', -3137.1592)], overall loss: -3137.1591796875
# Iteration: 22, named_losses: [('ActivationMax Loss', -3257.8152)], overall loss: -3257.815185546875
# Iteration: 23, named_losses: [('ActivationMax Loss', -3377.8914)], overall loss: -3377.891357421875
# Iteration: 24, named_losses: [('ActivationMax Loss', -3495.0952)], overall loss: -3495.09521484375
# Iteration: 25, named_losses: [('ActivationMax Loss', -3609.2827)], overall loss: -3609.28271484375
# Iteration: 26, named_losses: [('ActivationMax Loss', -3721.9595)], overall loss: -3721.95947265625
# Iteration: 194, named_losses: [('ActivationMax Loss', -20610.729)], overall loss: -20610.728515625
# Iteration: 195, named_losses: [('ActivationMax Loss', -20708.285)], overall loss: -20708.28515625
# Iteration: 196, named_losses: [('ActivationMax Loss', -20808.094)], overall loss: -20808.09375
# Iteration: 197, named_losses: [('ActivationMax Loss', -20906.79)], overall loss: -20906.7890625
# Iteration: 198, named_losses: [('ActivationMax Loss', -21006.09)], overall loss: -21006.08984375
# Iteration: 199, named_losses: [('ActivationMax Loss', -21104.541)], overall loss: -21104.541015625
# Iteration: 200, named_losses: [('ActivationMax Loss', -21202.92)], overall loss: -21202.919921875

# %% [markdown]
# It does indeed go to much lower values, but the image looks less natural. Let's try varous range of total variation weights to enforce naturalness.

# %%
for tv_weight in [1e-3, 1e-2, 1e-1, 1, 10]:
    # Lets turn off verbose output this time to avoid clutter and just see the output.
    img = visualize_activation(model, layer_idx, filter_indices=filter_idx, input_range=(0., 1.), 
                               tv_weight=tv_weight, lp_norm_weight=0.)
    plt.figure()
    plt.imshow(img[..., 0])

# %% [markdown]
# We can see how total variation loss is enforcing blobbiness. In this case the default value of `tv_weight=10` seems to work very well. The point of this exercise was to show how weights can be tuned.
#
# Lets visualize all other output categories and see what we get.

# %%
for output_idx in np.arange(10):
    # Lets turn off verbose output this time to avoid clutter and just see the output.
    img = visualize_activation(model, layer_idx, filter_indices=output_idx, input_range=(0., 1.))
    plt.figure()
    plt.title('Networks perception of {}'.format(output_idx))
    plt.imshow(img[..., 0])

# %% [markdown]
# Pretty cool. Its amazing that we can even generate an input image via backprop!
#
# Obviously you can tune the visualizations to look better by experimenting with `image_modifiers`, lp-norm weight etc. Basically, a regularizer is needed to enforce image naturalness prior to limit the input image search space. By this point, GANs should come to your mind. We could easily take a GAN trained on mnist and use discriminator loss as a regularizer. For using custom loss, you can use `visualize_activation_with_losses` API.
#
# Feel free to submit a PR if you try the GAN regularizer :)

# %% [markdown]
# ## Other fun stuff

# %% [markdown]
# The API to `visualize_activation` accepts `filter_indices`. This is generally meant for *multi label* classifiers, but nothing prevents us from having some fun.
#
# By setting `filter_indices=[1, 7]`, we can generate an input that the network thinks is both 1 and 7 simultaneously. Its like asking the network
#
# > Generate input image that you think is both 1 and a 7.

# %%
img = visualize_activation(model, layer_idx, filter_indices=[0, 3], input_range=(0., 1.))
plt.imshow(img[..., 0])

# %% [markdown]
# Compare this to the `1` generated above and you should be able to see the difference. Nifty indded!

# %% [markdown]
# ## Visualizations without swapping softmax

# %% [markdown]
# As alluded at the beginning of the tutorial, we want to compare and see what happens if we didnt swap out softmax for linear activation.

# %%
# Swap linear back with softmax
model.layers[layer_idx].activation = activations.softmax
model = utils.apply_modifications(model)

for output_idx in np.arange(10):
    # Lets turn off verbose output this time to avoid clutter and just see the output.
    img = visualize_activation(model, layer_idx, filter_indices=output_idx, input_range=(0., 1.))
    plt.figure()
    plt.title('Networks perception of {}'.format(output_idx))
    plt.imshow(img[..., 0])

# %% [markdown]
# It does not work! The reason is that maximizing an output node can be done by minimizing other outputs. Softmax is weird that way. It is the only activation that depends on other node output(s) in the layer.
